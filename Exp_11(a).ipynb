# %%
import pandas as pd
df=pd.read_csv('StkInter.csv')
df1=df[['Date','SP500','Long Interest Rate']]
X=df1[['SP500']]
Y=df1[['Long Interest Rate']]
import matplotlib.pyplot as plt
plt.scatter(X,Y,c="blue")
plt.xlabel("SP500")
plt.ylabel("Long Interest Rate")
plt.show()

# %%
from sklearn.model_selection import train_test_split
X=df1[['SP500']]
Y=df1['Long Interest Rate']
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20)
import numpy as np
X_train=np.asarray(X_train)
Y_train=np.asarray(Y_train)
X_test=np.asarray(X_test)
Y_test=np.asarray(Y_test)
X_train.reshape(1,-1)
Y_train.reshape(1,-1)
X_test.reshape(1,-1)
Y_test.reshape(1,-1)
# Out:
# array([[3.59, 4.34, 4.88, 3.74, 4.08, 4.72, 4.18, 2.82, 6.1 , 4.67, 4.5 ,
#         2.7 , 4.42, 3.56, 3.98, 4.73, 4.89, 5.16, 4.29, 4.76, 4.27, 3.83,
#         3.53, 4.73, 4.56, 4.57, 5.1 ]])

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
model=reg.fit(X_train,Y_train)
Y_pred=model.predict(X_test)
plt.scatter(Y_test,Y_pred,c='blue')

# %%
plt.scatter(X_test,Y_test,color='red')
plt.plot(X_train,reg.predict(X_train),color='blue')
plt.xlabel("SP500")
plt.ylabel("Long Interest Rate")
plt.show()
